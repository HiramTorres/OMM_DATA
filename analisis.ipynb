# %%
import pandas as pd  
import matplotlib.pyplot as plt 
import numpy as np
plt.style.use('seaborn')
plt.style.use(['dark_background'])

# %%
df = pd.read_csv("KPI MANTTO 4.0_PAROS DE LA BASE DE DATOS_Table.csv") 
print(df)
# Out:
#   ¿DE QUE ÁREA ERES? STATUS  Record Count
# 0  SEAT KING_LINEA 1  HECHO           109
# 1  SEAT KING_LINEA 2  HECHO            94
# 2  SEAT KING_LINEA 3  HECHO             2
# 3    SEAT KING_CORTE  HECHO             2

# %%
surveys = pd.read_csv("KPI MANTTO 4.0_PAROS DE LA BASE DE DATOS_Table.csv")
my_plot = surveys.plot()
plt.title("Grafica de paros")
plt.xlabel("Lineas")
plt.ylabel("Cantidad de eventos")
plt.show()

# %% [markdown]
# ## Gráficas paros acumulados
#
# >08/12/2021

# %%
data = pd.read_csv("KPI MANTTO 4.0_Copia de LISTADO DE MAQUINAS_Pivot table.csv")
datos  = pd.DataFrame(data)
no_serie = np.array(datos[["NO. SERIE"]])
paros = (datos[["PAROS ACUMULADOS"]])
print(datos)
# Out:
#             UBICACION        NO. SERIE                      MODELO  \
# 0   SEAT KING_LINEA 1       8L8QC00391                LU2818A70BBS
# 1   SEAT KING_LINEA 1       8L8NB00032                LU2810A70BBS
# 2   SEAT KING_LINEA 1       8L8QC00439  LU2818A70BBS/SC922BD/CP18C
# 3   SEAT KING_LINEA 1       8L8NB00033                LU2810A70BBS
# 4   SEAT KING_LINEA 1       8L8QC00399  LU2818A70BBS/SC922BD/CP18C
# 5   SEAT KING_LINEA 1       8L8QC00400  LU2818A70BBS/SC922BD/CP18C
# 6   SEAT KING_LINEA 1       8L8QC00407  LU2818A70BBS/SC922BD/CP18C
# 7   SEAT KING_LINEA 1       8L8QC00435  LU2818A70BBS/SC922BD/CP18C
# 8   SEAT KING_LINEA 2       8L8NB00031                LU2810A70BBS
# 9   SEAT KING_LINEA 2       8L8NB00030                LU2810A70BBS
# 10  SEAT KING_LINEA 2       4D0NJ10342                LU2810A70BBS
# 11  SEAT KING_LINEA 2       4D0NJ10262          DDL7000AS7NBD/AK-J
# 12  SEAT KING_LINEA 2       4D0NK02082          DDL7000AS7NBD/AK-J
# ...

# %%
paros.plot()
y = [0,20,40,60,80,100,120] 
plt.title("Grafica de maquinas Seatking")
plt.xlabel("Número de serie")
plt.ylabel("Minutos de paro")

plt.show()
