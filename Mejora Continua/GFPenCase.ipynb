# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")
fig = plt.figure(figsize=(10, 6))
dias = ["Dia 1", "Dia 2", "Dia 3", "Dia 4", "Día 5", "Día 6"]
produccion = [3,15,23, 27,27,13]
x = ["Acumulado total"]
y = [100]
plt.bar(dias, produccion, color="c")
plt.bar(x, y, color="c")
plt.plot(dias, produccion, color="r", marker="o", linestyle="dashdot")
plt.yticks(range(0, 101, 10))
plt.title("Pronostico de producción GF Pen Case")
plt.ylabel("Cantidad de piezas")
plt.xlabel("Días de producción")
plt.savefig("Pronostico_GF_Pen_Case.png")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_theme(style="whitegrid")

dias = ["Dia 1", "Dia 2", "Dia 3", "Dia 4", "Día 5", "Día 6"]
produccion = [
    int(input("Ingrese la producción del día 1: ")),
    int(input("Ingrese la producción del día 2: ")),
    int(input("Ingrese la producción del día 3: ")),
    int(input("Ingrese la producción del día 4: ")),
    int(input("Ingrese la producción del día 5: ")),
    int(input("Ingrese la producción del día 6: ")),
    ]
personas = [
    int(input("Ingrese la cantidad de personas que trabajan el día 1: ")),
    int(input("Ingrese la cantidad de personas que trabajan el día 2: ")),
    int(input("Ingrese la cantidad de personas que trabajan el día 3: ")),
    int(input("Ingrese la cantidad de personas que trabajan el día 4: ")),
    int(input("Ingrese la cantidad de personas que trabajan el día 5: ")),
    int(input("Ingrese la cantidad de personas que trabajan el día 6: ")),
]
ancho = 0.35
x = np.arange(len(dias))

fig, ax = plt.subplots()
graf1 = ax.bar(x-ancho/2, produccion, ancho, color="c")
graf2 = ax.bar(x+ancho/2, personas, ancho, color="m")
graf3 = ax.plot(x-ancho/2, produccion, color="r", marker="o", linestyle="dashdot")
ax.set_xticks(x)
ax.set_xticklabels(dias)
ax.legend((graf1[0], graf2[0],graf3[0]), ("Producción", "Personas","tendencia")) 
	
plt.title("Producción GF Pen Case")
plt.ylabel("Cantidad de piezas")
plt.xlabel("Días de producción")
plt.savefig("Produccion_GF_Pen_Case_17-08-22.png")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

fig = plt.figure(figsize=(10, 6))
dias = ["Dia 1", "Dia 2", "Dia 3", "Dia 4", "Día 5", "Día 6"]
#Acumulado total de producción gráfico aparte
x1 = produccion[0]
y = produccion[1]
z = produccion[2]
w = produccion[3]
t = produccion[4]
u = produccion[5]
sum = (x1 + y + z + w + t + u) 

plt.bar(dias, produccion, color="c")
plt.bar("Acumulado", sum, color="m")
plt.plot(dias, produccion, color="r", marker="o", linestyle="dashdot")
plt.yticks(range(0, 101, 10))
plt.title("Producción GF Pen Case")
plt.ylabel("Cantidad de piezas")
plt.xlabel("Días de producción")
plt.show()
