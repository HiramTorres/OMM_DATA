# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("db kpi - DB BOT.csv")
print(data)
# Out:
#       FOLIO STATUS           Timestamp ¿DE QUE ÁREA ERES?  \
# 0       1.0  HECHO   9/21/2021 7:32:26       PIEL_LINEA 4
# 1       2.0  HECHO   9/21/2021 8:51:34       PIEL_LINEA 6
# 2       3.0  HECHO   9/21/2021 8:55:41       PIEL_LINEA 6
# 3       4.0  HECHO  9/21/2021 12:29:16       PIEL_LINEA 2
# 4       5.0  HECHO   9/22/2021 8:30:28       PIEL_LINEA 3
# ...     ...    ...                 ...                ...
# 4994    NaN    NaN                 NaN                NaN
# 4995    NaN    NaN                 NaN                NaN
# 4996    NaN    NaN                 NaN                NaN
# 4997    NaN    NaN                 NaN                NaN
# 4998    NaN    NaN                 NaN                NaN
#
#      ¿QUE IMPACTO TENDRIA SI NO SE CUMPLE EN EL TIEMPO SOLICITADO?  \
# 0                                         Paro de linia
# 1                      personal  tiene poca visivilidad
# 2                        retrazo en proceso de producto
# ...

# %%
data.dropna(axis=0)
data
# Out:
#       FOLIO STATUS           Timestamp ¿DE QUE ÁREA ERES?  \
# 0       1.0  HECHO   9/21/2021 7:32:26       PIEL_LINEA 4
# 1       2.0  HECHO   9/21/2021 8:51:34       PIEL_LINEA 6
# 2       3.0  HECHO   9/21/2021 8:55:41       PIEL_LINEA 6
# 3       4.0  HECHO  9/21/2021 12:29:16       PIEL_LINEA 2
# 4       5.0  HECHO   9/22/2021 8:30:28       PIEL_LINEA 3
# ...     ...    ...                 ...                ...
# 4994    NaN    NaN                 NaN                NaN
# 4995    NaN    NaN                 NaN                NaN
# 4996    NaN    NaN                 NaN                NaN
# 4997    NaN    NaN                 NaN                NaN
# 4998    NaN    NaN                 NaN                NaN
#
#      ¿QUE IMPACTO TENDRIA SI NO SE CUMPLE EN EL TIEMPO SOLICITADO?  \
# 0                                         Paro de linia
# 1                      personal  tiene poca visivilidad
# 2                        retrazo en proceso de producto
# ...
