# %% [markdown]
# # Revisión con pandas.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_excel('Datos/SBL-30-372_GRANDFATHER PEN CASE.xlsx')
df.head(5)
# Out:
#   SECUENCIA DE OPERACIONES PARA GRANDFATHER PEN CASE SBL-30-372 Unnamed: 1  \
# 0                                                NaN                   NaN
# 1                                                NaN                   NaN
# 2                                                NO.              MÁQUINA
# 3                                                  1                   NaN
# 4                                                  2                   NaN
#
#   Unnamed: 2                Unnamed: 3         Unnamed: 4    SEG/PZA  \
# 0        NaN                       NaN                NaN    MIN/PZA
# 1        NaN                       NaN                NaN     HR/PZA
# 2   TRABAJO     NOMBRE DE LA FRACCION   TIPO DE OPERARIO   BALANCEO
# 3        NaN  PREPARAR Y CONTAR TAREA                 NaN        NaN
# 4        NaN  RAYAR LATERAL DE CUERPO                 NaN        NaN
#
#         21296.35 Unnamed: 7  Unnamed: 8 Unnamed: 9  Unnamed: 10 Unnamed: 11
# ...
